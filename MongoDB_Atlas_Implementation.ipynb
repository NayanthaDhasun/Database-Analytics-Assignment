# %% [markdown]
# <a href="https://colab.research.google.com/github/NayanthaDhasun/Database-Analytics-Assignment/blob/main/MongoDB_Atlas_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo

from pymongo import MongoClient
import pandas as pd

username = "nayanthasr_db_user"
password = "pyaEWLo1lpTBb5Bn"

client = MongoClient(
    f"mongodb+srv://{username}:{password}@cluster0.vwryx52.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
)

db = client["northstar_db"]

client.admin.command("ping")
print("MongoDB connected successfully")

deliveries = pd.read_csv("deliveries.csv")
deliveries_data = deliveries.to_dict("records")

db.deliveries.insert_many(deliveries_data)

db.deliveries.find_one()

db.customers.insert_one({
    "customer_id":"C100",
    "customer_name":"David"
})

db.customers.find_one({
    "customer_id":"C100"
})

db.customers.update_one(
    {"customer_id":"C100"},
    {"$set":{"customer_name":"David Silva"}}
)

db.customers.delete_one({
    "customer_id":"C100"
})

list(db.deliveries.aggregate([
    {
        "$group":{
            "_id":"$delivery_status",
            "total_deliveries":{"$sum":1}
        }
    }
]))

list(db.deliveries.aggregate([
    {
        "$group":{
            "_id":"$delivery_status",
            "average_cost":{
                "$avg":"$fuel_or_charge_cost"
            }
        }
    }
]))

list(db.deliveries.find({
    "delivery_status": "Failed"
}))

db.deliveries.find({
    "delivery_status": "Failed"
}).explain()


db.deliveries.create_index("delivery_status")

list(db.deliveries.find({
    "delivery_status": "Failed"
}))

db.deliveries.find({
    "delivery_status": "Failed"
}).explain()
# Out:
# ...
# MongoDB connected successfully
# {'explainVersion': '1',
#  'queryPlanner': {'namespace': 'northstar_db.deliveries',
#   'parsedQuery': {'delivery_status': {'$eq': 'Failed'}},
#   'indexFilterSet': False,
#   'queryHash': 'CC376D25',
#   'planCacheShapeHash': 'CC376D25',
#   'planCacheKey': '36D9B181',
#   'optimizationTimeMillis': 0,
#   'maxIndexedOrSolutionsReached': False,
#   'maxIndexedAndSolutionsReached': False,
#   'maxScansToExplodeReached': False,
#   'prunedSimilarIndexes': False,
#   'winningPlan': {'isCached': False,
#    'stage': 'FETCH',
#    'inputStage': {'stage': 'IXSCAN',
#     'keyPattern': {'delivery_status': 1},
#     'indexName': 'delivery_status_1',
#     'isMultiKey': False,
#     'multiKeyPaths': {'delivery_status': []},
#     'isUnique': False,
#     'isSparse': False,
#     'isPartial': False,
#     'indexVersion': 2,
#     'direction': 'forward',
#     'indexBounds': {'delivery_status': ['["Failed", "Failed"]']}}},
#   'rejectedPlans': []},
# ...
